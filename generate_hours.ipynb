# %%
import openai
import random
import numpy as np
import json
import time
from datetime import datetime, timedelta

# %%
from openai import OpenAI
client = OpenAI(
  api_key='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'
  # base_url="http://cooper.k8s.nb-prod.com/v1"
)

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "Generate a list of 1000 made up restaurants. Use a bullet point format, and start with a variety of words."}],
    max_tokens=4096,
    temperature=1.0
)
names_str = response.choices[0].message.content
names_str
# Out:
# "- The Twisted Fork\n- Fireside Grill\n- Sunny Side Cafe\n- Ocean Breeze Bistro\n- Rustic Tavern\n- Spice Island Kitchen\n- Moonlight Diner\n- Whispering Pines Steakhouse\n- Bluebird Bakery\n- Sizzling Sushi Bar\n- Harvest Moon Deli\n- Divine Desserts\n- The Hungry Hippo\n- Tropical Oasis Restaurant\n- Lush Garden Cafe\n- Golden Harvest Buffet\n- Sunrise Cafe\n- Dragonfly Lounge\n- Maple Leaf Bistro\n- The Cozy Cabin\n- Zesty Food Truck\n- The Roaming Ramen\n- Bellissimo Italian Ristorante\n- Tiki Hut Tacos\n- Diamond Grill\n- Silver Spoon Steakhouse\n- The Green Leaf Cafe\n- Red Velvet Cafe\n- The Noodle House\n- Lemon Drop Bakery\n- Purple Plum Cafe\n- Heavenly Brews Coffee Shop\n- The Blue Plate\n- The Gourmet Garden\n- Whispering Woods Cafe\n- Misty Mountain Diner\n- Urban Fusion Bistro\n- Jade Palace\n- The Rooster's Nest\n- Fireside Bar and Grill\n- Fresh Catch Seafood Restaurant\n- The Wandering Fork\n- Ocean View Cafe\n- Copper Kettle Pub\n- Spice Route Bistro\n- The Whimsica
# ...

# %%
from openai import OpenAI
client = OpenAI(
  api_key='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'
  # base_url="http://cooper.k8s.nb-prod.com/v1"
)

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": "generate a list of around 10 different objectively verifiable question formats in which an LLM like GPT can test its sense of time"}],
    max_tokens=4096,
    temperature=1.0
)
names_str = response.choices[0].message.content
print(names_str)
# Out:
# 1. How many minutes are in one hour?
# 2. What is the time difference between 9:30 AM and 3:45 PM?
# 3. If a meeting starts at 11:15 AM and lasts for 2 hours and 30 minutes, what time will it end?
# 4. How many seconds are in a day?
# 5. If a train leaves the station at 5:45 PM and arrives at its destination at 10:30 PM, how long was the journey?
# 6. If a recipe requires baking for 45 minutes at 350 degrees Fahrenheit, what time should you take it out of the oven if you put it in at 4:15 PM?
# 7. How many hours are in a 7-day week?
# 8. If a marathon starts at 8:00 AM and the average runner finishes in 4 hours and 30 minutes, what time can you expect the winner to cross the finish line?
# 9. How many milliseconds are in one second?
# 10. If a movie starts at 7:30 PM and has a runtime of 2 hours and 15 minutes, what time will it end?

# %%
hours_txt = []
for i in range(100):
    row = data[i]
    hours = row['hours']
    hours = '\n'.join([f"    {day}: {hours[day] if hours[day] != '' else 'Closed'}" for day in hours])
    hours_txt.append(row['name'] + '\n' + hours)

hours_txt = "\n\n".join(hours_txt)
hours_txt
# Out:
# "Magnolia Gardens\n    Fri: 00:45AM-11:15PM\n    Mon: 02:30AM-06:45AM, 04:15PM-04:15PM\n    Sat: 05:15PM-08:45PM\n    Sun: 04:30AM-01:00PM, 09:45PM-10:00PM\n    Thu: 05:30AM-09:15AM, 01:00PM-05:45PM\n    Tue: 01:45PM-02:30PM\n    Wed: 02:30AM-05:45AM, 11:30AM-09:45PM\n\nThe Nutcracker Sweets Bakery\n    Fri: 02:15AM-11:45PM\n    Mon: 10:00AM-02:30PM, 08:00PM-08:15PM\n    Sat: 00:30AM-10:45AM, 02:30PM-11:00PM\n    Sun: 00:30AM-01:45AM, 02:15PM-11:45PM\n    Thu: 01:30AM-02:00PM\n    Tue: 01:00PM-06:15PM\n    Wed: 00:00PM-10:15PM\n\nThe Jubilee Juice Bar\n    Fri: 07:30AM-09:15PM\n    Mon: 00:30AM-06:30AM, 07:15PM-11:30PM\n    Sat: 01:30AM-10:00AM, 08:00PM-10:30PM\n    Sun: 03:30AM-05:30AM, 04:30PM-11:45PM\n    Thu: 08:00AM-08:00PM\n    Tue: 00:15AM-03:30AM\n    Wed: 05:15AM-07:15AM, 08:45PM-10:45PM\n\nThe Pita Pit\n    Fri: 09:45AM-10:00PM\n    Mon: 03:00AM-08:15AM, 03:30PM-05:00PM\n    Sat: 06:15AM-00:30PM, 05:15PM-09:15PM\n    Sun: 00:15AM-11:30AM\n    Thu: 09:15AM-00:30PM, 02:30PM-0
# ...

# %%
from openai import OpenAI
client = OpenAI(
  api_key='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'
  # base_url="http://cooper.k8s.nb-prod.com/v1"
)

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
      {"role": "system", "content": "You are a helpful assistant in dataset generation. You are efficient at generating questions and only giving those in the form of a python list."},
      {"role": "user", "content": f"I want to generate a dataset for LLM training, where the key information offered is"
                                  f"an exact time (in a datetime variable called 'final_time') information in the form of datetime.strftime() "
                                  f"The LLM would also be given a database of all the "
                                  f"restaurants in the question - a JSON file containing the name of a restaurant and their opening hours. "
                                  f"Give me some varied prompt templates to test the LLM's capabilities through offering the question in a variety of ways, "
                                  f"specifically, asking the LLM to return all the restaurants that are open 'tomorrow' (i.e. "
                                  f"f'Which restaurants are open tomorrow at {{final_time:%-I:%M%p}}?)"
                                  # f"f'{{time_delta.days}} days later, what restaurants can I go to?',)."
                                  f"write your answers in the form of python f-strings. Do not use words like 'provided.'"}],
    max_tokens=4096,
    temperature=1.0
)
names_str = response.choices[0].message.content
print(names_str)
# Out:
# [
#     f"Can you list the restaurants available tomorrow at {final_time:%-I:%M%p}?",
#     f"Which dining places are open tomorrow at {final_time:%-I:%M%p}?",
#     f"Tell me the restaurants operating tomorrow at {final_time:%-I:%M%p}.",
#     f"I need to know the eateries open tomorrow at {final_time:%-I:%M%p}.",
#     f"Find the restaurants that have opened tomorrow at {final_time:%-I:%M%p}.",
#     f"What restaurants will be serving tomorrow at {final_time:%-I:%M%p}?",
#     f"Could you show the restaurants open tomorrow at {final_time:%-I:%M%p}?",
#     f"Please list out the restaurants open tomorrow at {final_time:%-I:%M%p}.",
#     f"Which food spots will be available tomorrow at {final_time:%-I:%M%p}?",
#     f"Identify the food places that will be operational tomorrow at {final_time:%-I:%M%p}"
# ]

# %%
res_name = "Olive Garden"
final_time = datetime.now()
time_delta = timedelta(days=1)
prompts = [
    f"The current time is {final_time:%Y-%m-%d %H:%M:%S}. Which restaurants are open right now?",
    f"It's {final_time:%A, %B %d at %I:%M %p} and I'd like to know which restaurants are open.",
    f"If the time is {final_time:%m/%d/%Y %H:%M} right now, can you list the restaurants that are currently open?",
    f"Given that it is currently {final_time:%I:%M %p on %A, %B %d, %Y}, what restaurants remain open?",
    f"At this exact moment, it's {final_time:%H:%M on %d-%m-%Y}. Please list all the open restaurants.",
    f"The exact time currently is {final_time:%I:%M:%S %p, %b %d, %Y}. Which restaurants are open now?",
    f"Can you tell me the open restaurants if the time is now {final_time:%H:%M:%S} on {final_time:%B %d}?",
    f"Tell me the restaurants that are open at {final_time:%H:%M on %d/%m/%Y}.",
    f"Suppose it is currently {final_time:%A at %I:%M %p}. Which places are open?",
    f"If it's {final_time:%b %d, %Y, %H:%M %p}, what restaurants can I go to?",
    f"It’s {final_time:%H:%M:%S on %A, %B %d, %Y}. Which restaurants should be open now?",
    f"The time is currently {final_time:%d-%m-%Y %H:%M}. Can you list the restaurants that are still open?",
    f"Find the restaurants open at {final_time:%A, %d %b %Y %H:%M:%S}.",
    f"It’s {final_time:%I:%M %p on %Y-%m-%d}. What restaurants are open at this time?"
]

prompts, time
# Out:
# (['The current time is 2024-06-19 19:53:19. Which restaurants are open right now?',
#   "It's Wednesday, June 19 at 07:53 PM and I'd like to know which restaurants are open.",
#   'If the time is 06/19/2024 19:53 right now, can you list the restaurants that are currently open?',
#   'Given that it is currently 07:53 PM on Wednesday, June 19, 2024, what restaurants remain open?',
#   "At this exact moment, it's 19:53 on 19-06-2024. Please list all the open restaurants.",
#   'The exact time currently is 07:53:19 PM, Jun 19, 2024. Which restaurants are open now?',
#   'Can you tell me the open restaurants if the time is now 19:53:19 on June 19?',
#   'Tell me the restaurants that are open at 19:53 on 19/06/2024.',
#   'Suppose it is currently Wednesday at 07:53 PM. Which places are open?',
#   "If it's Jun 19, 2024, 19:53 PM, what restaurants can I go to?",
#   'It’s 19:53:19 on Wednesday, June 19, 2024. Which restaurants should be open now?',
# ...

# %%
def generate_hours(lower = 0, upper = 24):
    
    
    def to_analog(n):
        is_pm = n >= 12
        if is_pm:
            n -= 12
        
        hrs = n // 1
        if hrs % 12 == 0:
            hrs += 12
        mins = (n % 1) * 60 // 1
        mins = (mins // 15) * 15
        return "%02.0f:%02.0f%s" % (hrs, mins, "PM" if is_pm else "AM")
    
    a, b = 0, 0
    while (to_analog(a) == to_analog(b)):
        a, b = np.random.uniform(lower, upper, (2))
    
    if b < a:
        a, b = b, a
    return f"{to_analog(a)}-{to_analog(b)}"

def generate_daily_hours():
    rand = random.random()
    if rand < 0.1:
        return ""
    
    if rand < 0.6:
        return generate_hours()
        
    split = random.randint(11, 16)
    return f"{generate_hours(upper=split)}, {generate_hours(lower=split)}"

def generate_weekly_hours():
    out = {}
    days = ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')
    for day in days:
        out[day] = generate_daily_hours()
    return out

# %%
def generate_dataset():
    ds = []
    f = open('names.txt', 'r')
    for name in f:
        name = name.split('\n')[0]
        row = {}
        row["name"] = name
        row["hours"] = generate_weekly_hours()
        ds.append(row)
    return ds

ds = generate_dataset()
print(ds)
# Out:
# [{'name': 'Magnolia Gardens', 'hours': {'Mon': '', 'Tue': '12:45AM-07:30PM', 'Wed': '03:45AM-06:45AM, 03:00PM-05:15PM', 'Thu': '12:15AM-04:15PM', 'Fri': '01:00PM-05:45PM', 'Sat': '08:00PM-08:30PM', 'Sun': '02:15AM-09:30AM, 04:15PM-10:15PM'}}, {'name': 'The Nutcracker Sweets Bakery', 'hours': {'Mon': '06:15AM-09:30AM, 11:30AM-08:00PM', 'Tue': '04:30AM-03:00PM', 'Wed': '01:00PM-04:45PM', 'Thu': '06:15AM-10:00AM, 05:15PM-10:30PM', 'Fri': '12:15AM-08:15AM', 'Sat': '10:15AM-03:45PM', 'Sun': '05:30PM-08:30PM'}}, {'name': 'The Jubilee Juice Bar', 'hours': {'Mon': '', 'Tue': '11:30AM-01:15PM, 04:00PM-11:45PM', 'Wed': '09:00AM-10:30AM', 'Thu': '12:15AM-01:00AM', 'Fri': '09:30AM-12:15PM', 'Sat': '03:45AM-02:30PM', 'Sun': '05:00AM-11:30AM, 02:30PM-06:45PM'}}, {'name': 'The Pita Pit', 'hours': {'Mon': '01:30AM-09:45AM', 'Tue': '01:15AM-10:00PM', 'Wed': '02:15AM-07:30AM, 12:30PM-07:00PM', 'Thu': '11:30AM-01:45PM', 'Fri': '03:00AM-06:15AM, 06:15PM-09:30PM', 'Sat': '', 'Sun': '08:15AM-04:45PM'}}, {
# ...

# %%
import json
f = open('hours_dataset.json', 'a')
f.write(json.dumps({'bar': ('baz', None, 1.0, 2)}))
f.write("\u000a")
f.close()

# %%
from openai import OpenAI
client = OpenAI(
  api_key='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'
  # base_url="http://cooper.k8s.nb-prod.com/v1"
)

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": "what is 1 + 1?"},
        {"role": "user", "content": "what is 1 + 2?"},
    ],
    max_tokens=4096,
    temperature=1.0,
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 from openai import OpenAI
#       2 client = OpenAI(
#       3   api_key='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'
#       4   # base_url="http://cooper.k8s.nb-prod.com/v1"
#       5 )
# ----> 7 response = client.chat.completions.create(
#       8     model="gpt-3.5-turbo",
#       9     messages=[
#      10         {"role": "user", "content": "what is 1 + 1?"},
#      11         {"role": "user", "content": "what is 1 + 2?"},
#      12     ],
#      13     prompts=["what is 1 + 1?", "what is 1 + 2?"],
#      14     max_tokens=4096,
#      15     temperature=1.0
#      16 )
#      17 print(response)
#
# File ~/miniconda3/envs/wxg/lib/python3.11/site-packages/openai/_utils/_utils.py:303, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...

# %%
print(response.choices)
# Out:
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1 + 2 is equal to 3.', role='assistant', function_call=None, tool_calls=None))]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_id = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)

messages = [
    {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
    {"role": "user", "content": "Who are you?"},
]

input_ids = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    return_tensors="pt"
).to(model.device)

terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

outputs = model.generate(
    input_ids,
    max_new_tokens=256,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.6,
    top_p=0.9,
)
response = outputs[0][input_ids.shape[-1]:]
print(tokenizer.decode(response, skip_special_tokens=True))
# Out:
# /home/paperspace/miniconda3/envs/wxg/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 6
#       2 import torch
#       4 model_id = "meta-llama/Meta-Llama-3-8B-Instruct"
# ----> 6 tokenizer = AutoTokenizer.from_pretrained(model_id)
#       7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_id,
#       9     torch_dtype=torch.bfloat16,
#      10     device_map="auto",
#      11 )
#      13 messages = [
#      14     {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
#      15     {"role": "user", "content": "Who are you?"},
# ...

# %%
print("{\n    \"time\": \"2028-11-24 12:00AM\",\n    \"day_of_week\": \"Fri\",\n    \"opening_hours\": {\n        \"Flavor Fields\": \"Closed\",\n        \"The Hidden Herb\": \"Closed\",\n        \"Flavor Junction\": \"06:30AM-08:00PM\"\nToday is 2028-11-24 12:00AM. 'Flavor Fields' is closed on Fridays as indicated by the empty opening hours, while 'The Hidden Herb' is closed all day on Fridays.\",\n        'Flavor Junction' is open from 06:30AM to 08:00PM on Fridays, which is after the specified time of 12:00AM.\",\n    },\n    \"reasoning\": {\n        \"Flavor Fields\": \"Flavor Fields is closed on Fridays.\",\n        \"The Hidden Herb\": \"The Hidden Herb is closed all day on Fridays.\",\n        \"Flavor Junction\": \"Flavor Junction is open from 06:30AM to 08:00PM on Fridays, which is after the specified time of 12:00AM.\"\n    },\n    \"is_open\": []\n} ")
# Out:
# {
#     "time": "2028-11-24 12:00AM",
#     "day_of_week": "Fri",
#     "opening_hours": {
#         "Flavor Fields": "Closed",
#         "The Hidden Herb": "Closed",
#         "Flavor Junction": "06:30AM-08:00PM"
# Today is 2028-11-24 12:00AM. 'Flavor Fields' is closed on Fridays as indicated by the empty opening hours, while 'The Hidden Herb' is closed all day on Fridays.",
#         'Flavor Junction' is open from 06:30AM to 08:00PM on Fridays, which is after the specified time of 12:00AM.",
#     },
#     "reasoning": {
#         "Flavor Fields": "Flavor Fields is closed on Fridays.",
#         "The Hidden Herb": "The Hidden Herb is closed all day on Fridays.",
#         "Flavor Junction": "Flavor Junction is open from 06:30AM to 08:00PM on Fridays, which is after the specified time of 12:00AM."
#     },
#     "is_open": []
# }

# %%
json_schema = {
    "properties": {
        "location": {
            "type": "string"
        },
        "activity": {
            "type": "string"
        },
        "animals_seen": {
            "type": "integer",
            "minimum": 1,
            "maximum": 5
        },
        "animals": {
            "type": "array",
            "items": {
                "type": "string"
            }
        }
    },
    "required": ["location", "activity", "animals_seen", "animals"]
}
